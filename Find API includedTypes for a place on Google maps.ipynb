# %% [markdown]
# <a href="https://colab.research.google.com/github/alixtrn/QM2-Final-Project---Childhood-Obesity-in-London/blob/main/Find%20API%20includedTypes%20for%20a%20place%20on%20Google%20maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First, let's set up your API key. Even though you provided it, I'll show the secure way to access it from Colab secrets, which is good practice for production environments.

# %%
# To store your API key securely, you would add it to Colab's 'Secrets' feature.
# For this demonstration, I'll use the key you provided directly.
# In a real scenario, you would use: GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

import requests
from google.colab import userdata # For secure key storage best practices

# Using the API key you provided for demonstration purposes
GOOGLE_API_KEY = 'AIzaSyC2RleANtod74mwmXYiH0q1_52EUmlvLGg'

print("API Key loaded. Remember to use Colab's Secrets for secure storage in your projects!")
# Out:
# API Key loaded. Remember to use Colab's Secrets for secure storage in your projects!

# %% [markdown]
# Now, let's use the Google Places Text Search API to find a famous landmark and extract its types. We'll search for 'Eiffel Tower' as an example.

# %%
search_query = "YO! Sushi"
places_api_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

params = {
    'query': search_query,
    'key': GOOGLE_API_KEY
}

response = requests.get(places_api_url, params=params)
response_data = response.json()

if response_data['status'] == 'OK' and response_data['results']:
    first_place = response_data['results'][0]
    place_name = first_place.get('name')
    place_types = first_place.get('types', [])

    print(f"Place found: {place_name}")
    print(f"API-included Types for '{place_name}': {', '.join(place_types)}")
else:
    print(f"Could not find a place for query '{search_query}'. Status: {response_data.get('status')}")
    if 'error_message' in response_data:
        print(f"Error: {response_data['error_message']}")
# Out:
# Place found: Yo!Sushi Kitchen
# API-included Types for 'Yo!Sushi Kitchen': restaurant, food, point_of_interest, establishment

# %% [markdown]
# This code demonstrates how to retrieve the categories (`types`) associated with a specific place. If you need a comprehensive list of all supported place types by the Google Places API, please refer to the [official documentation](https://developers.google.com/maps/documentation/places/web-service/supported_types).
